# %% [markdown]
# <a href="https://colab.research.google.com/github/iqraghori/Data-science/blob/main/Pandas_practice/task%2301(basic%20data%20filtering%20using%20pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
# code here
import numpy as np
import pandas as pd

print(type(pd.Series()))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
# code here
series1 = pd.Series([1,2,3,4,5,6])
series2 = pd.Series([1,2,3,4])
# print(series1 + series2,fill_value=0)
print(series1.add(series2, fill_value = 0))
print(series1.multiply(series2, fill_value = 1))
# Out:
# 0    2.0
# 1    4.0
# 2    6.0
# 3    8.0
# 4    5.0
# 5    6.0
# dtype: float64
# 0     1.0
# 1     4.0
# 2     9.0
# 3    16.0
# 4     5.0
# 5     6.0
# dtype: float64

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
# code here
s1 = pd.Series([2, 4, 6, 8, 10])
s2 = pd.Series([1, 3, 5, 7, 10])
print( s1 == s2)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ###`Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
# code here
series = pd.Series([1,2,'Python', 2.0, True, 100])
pd.to_numeric(series, errors='coerce')
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
# code here
ipl = pd.read_csv('/content/batsman_runs_series.csv')
ipl.sort_values('batsman_run', ascending=False).head(10)
# Out:
#              batter  batsman_run
# 569         V Kohli         6634
# 462        S Dhawan         6244
# 130       DA Warner         5883
# 430       RG Sharma         5881
# 493        SK Raina         5536
# 27   AB de Villiers         5181
# 108        CH Gayle         4997
# 339        MS Dhoni         4978
# 452      RV Uthappa         4954
# 256      KD Karthik         4377

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
# code here
ipl[ipl['batsman_run'] > 3000]['batsman_run'].count()
# Out:
# np.int64(20)

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?

# %%
# code here
print(ipl['batsman_run'].mean())
ipl[(ipl['batsman_run']) > (ipl['batsman_run'].mean())]['batter'].count()
# Out:
# 464.42809917355373
# np.int64(128)

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %%
items = pd.read_csv('/content/items.csv', index_col='item_name')
items.head()
# Out:
#                                       item_price
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98

# %% [markdown]
# ###`Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     ii. Item price is given in $, so convert it to rupees without currency symbol.
#     iii. Make data type of newly made series as float.
#     iv. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
# code here

print(items.isnull().sum())
items['item_price'] = items['item_price'].str.replace('$', '').str.strip().astype(float)
items['item_price'] = items['item_price'] * 278
items['item_price'] = items['item_price'].fillna(items['item_price'].mean())
items.isnull().sum()
items
# Out:
# item_price    50
# dtype: int64
#                                        item_price
# item_name
# Chips and Fresh Tomato Salsa               664.42
# Izze                                       942.42
# Nantucket Nectar                           942.42
# Chips and Tomatillo-Green Chili Salsa      664.42
# Chicken Bowl                              4720.44
# ...                                           ...
# Steak Burrito                             3266.50
# Steak Burrito                             3266.50
# Chicken Salad Bowl                        3127.50
# Chicken Salad Bowl                        2432.50
# Chicken Salad Bowl                        2432.50
#
# [4622 rows x 1 columns]

# %% [markdown]
# ###`Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
# code here
np.percentile(items['item_price'], 30)
np.percentile(items['item_price'], 60)
items['item_price'].hist(bins=50)
items[(items['item_price'] > 1000) & (items['item_price'] < 2000)]
# Out:
#                      item_price
# item_name
# Chips and Guacamole      1237.1
# Chips and Guacamole      1237.1
# Chips and Guacamole      1237.1
# Chips and Guacamole      1237.1
# Chips and Guacamole      1237.1
# ...                         ...
# Chips and Guacamole      1237.1
# Chips and Guacamole      1237.1
# Chips and Guacamole      1237.1
# Chips and Guacamole      1237.1
# Chips and Guacamole      1237.1
#
# [555 rows x 1 columns]
