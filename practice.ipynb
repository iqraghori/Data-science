# %% [markdown]
# <a href="https://colab.research.google.com/github/iqraghori/Data-science/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
f = open('sample.txt','w')
f.write("ellow")
#f.close()
f.write("hi")

# %%
f= open('sample1.txt','w')
f.write("how are you")
f.write("\n you doiing fine?")
f.close()

# %%
l = ['hello\n','how are you\n','you doing fine?']
f= open('sample.txt','w')
f.writelines(l)
f.close()

# %%
with open('sample.txt','r') as f:
  print(f.read())
  f.seek(0)
  f.write('X')
  print(f.read())

# %%
with open('/Screenshot (167).png','r') as f:
  f.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipython-input-3465649643.py in <cell line: 0>()
#       1 with open('/Screenshot (167).png','r') as f:
# ----> 2   f.read()
#
# /usr/lib/python3.12/codecs.py in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte

# %%
with open('/Screenshot (167).png','rb') as f:
  with open('new_ss.png','wb') as wf:
    wf.write(f.read())

# %%
print("hello")
# Out:
# hello

# %%
class Point:
  def __init__(self, x, y):
    self.x_cod = x
    self.y_cod = y
  def __str__(self):
    return f"<{self.x_cod},{self.y_cod}>"
   #return "({},{})".format(self.x_cod,self.y_cod)

  def euclidianDistance(self,other):
    return (self.x_cod - other.x_cod)**2 + (self.y_cod - other.y_cod)**2

  def distanceFromOrigin(self):
    return self.euclidianDistance(Point(0,0))

class Line:
  def __init__(self,a,b,c):
    self.a=a
    self.b=b
    self.c=c
  def __str__(self):
    return f"{self.a}x + {self.b}y + {self.c} = 0"

  def pointOnLine(self,point):
    if self.a*point.x_cod + self.b*point.y_cod + self.c == 0:
      return True
    else:
      return False

  def shortestDistance(self,point):
    return abs(self.a*point.x_cod + self.b*point.y_cod + self.c)/(self.a**2 + self.b**2)**2

p1 = Point(1,2)
p2 = Point(3,4)
p1.euclidianDistance(p2)
p2.distanceFromOrigin()
l1 = Line(3,4,5)
l2 = Line(1,2,3)
l3 = Line(1,1,-2)
p3 = Point(1,2)
print(l1)
l2.pointOnLine(p2)
l3.shortestDistance(p3)
# Out:
# 3x + 4y + 5 = 0
# 0.25

# %% [markdown]
# #inheritance

# %%
class Phone:
  def __init__(self,price,brand,camera):
    print("inside phone consructor")
    self.__price = price
    self.brand = brand
    self.camera = camera

class SmartPhone(Phone):
  def __init__(self,price,brand,camera,os,ram):
    print("indide smartphone constructor")
    super().__init__(price,brand ,camera)
    self.os = os
    self.ram=ram
    print("inside smartphone constructor")

s1 = SmartPhone(20000,"samsung",12,"android",2)
# Out:
# indide smartphone constructor
# inside phone consructor
# inside smartphone constructor
